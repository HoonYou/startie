# %% [markdown]
# # Startie PPT Visual Assets
#
# This notebook reproduces the visual assets used for the presentation deck.
#
# Sources:
# - `context/02_data_dictionary.md`
# - `context/03_analysis_guide.md`
# - `context/05_ceo_questions.md`
#
# Notes:
# - Event-based visuals are limited by the observed log window starting on 2025-01-06.
# - Output images are saved to `deliverables/results/`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
if str(ROOT / "src") not in sys.path:
    sys.path.append(str(ROOT / "src"))

from generate_ppt_visual_assets import main

# %%
main()
# Out:
# C:\Users\user\hoon\projects\startie_product_analysis\src\generate_ppt_visual_assets.py:242: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   exp_full["onboarding_completed"] = exp_full["onboarding_completed"].fillna(False).astype(bool)
# C:\Users\user\hoon\projects\startie_product_analysis\src\generate_ppt_visual_assets.py:243: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   exp_full["aha"] = exp_full["aha"].fillna(False).astype(bool)

# %%
results_dir = ROOT / "deliverables" / "results"
sorted([p.name for p in results_dir.glob("*.png")])
# Out:
# ['slide03_overview_trend.png',
#  'slide07_value_gap_diagnostics.png',
#  'slide08_aha_kpi.png',
#  'slide09_onboarding_improvement.png',
#  'slide12_checkout_dropoff.png',
#  'slide13_cs_intervention_effect.png',
#  'slide14_expected_impact_summary.png',
#  'slide14_mau_forecast_6m.png']

# %% [markdown]
# ## Preview
#
# The cells below display a few core assets.

# %%
from IPython.display import Image, display

for name in [
    "slide07_value_gap_diagnostics.png",
    "slide08_aha_kpi.png",
    "slide09_onboarding_improvement.png",
    "slide12_checkout_dropoff.png",
    "slide13_cs_intervention_effect.png",
    "slide14_expected_impact_summary.png",
]:
    display(Image(filename=str(results_dir / name)))
